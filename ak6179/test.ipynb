# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.rcParams['figure.figsize'] = 12, 12

# %%
countries = pd.read_csv("../countries.csv")

# %%
gdp_df = pd.read_excel("../indicator gapminder gdp_per_capita_ppp.xlsx")

# %%
countries
# Out:
#                               Country         Region
# 0                             Algeria         AFRICA
# 1                              Angola         AFRICA
# 2                               Benin         AFRICA
# 3                            Botswana         AFRICA
# 4                             Burkina         AFRICA
# 5                             Burundi         AFRICA
# 6                            Cameroon         AFRICA
# 7                          Cape Verde         AFRICA
# 8            Central African Republic         AFRICA
# 9                                Chad         AFRICA
# 10                            Comoros         AFRICA
# 11                              Congo         AFRICA
# 12      Congo, Democratic Republic of         AFRICA
# 13                           Djibouti         AFRICA
# 14                              Egypt         AFRICA
# 15                  Equatorial Guinea         AFRICA
# 16                            Eritrea         AFRICA
# ...

# %%
gdp_df.dtypes
# Out:
# gdp pc test     object
# 1800           float64
# 1801           float64
# 1802           float64
# 1803           float64
# 1804           float64
# 1805           float64
# 1806           float64
# 1807           float64
# 1808           float64
# 1809           float64
# 1810           float64
# 1811           float64
# 1812           float64
# 1813           float64
# 1814           float64
# 1815           float64
# 1816           float64
# 1817           float64
# 1818           float64
# 1819           float64
# 1820           float64
# 1821           float64
# 1822           float64
# 1823           float64
# 1824           float64
# 1825           float64
# 1826           float64
# 1827           float64
# 1828           float64
#                 ...
# 1983           float64
# 1984           float64
# 1985           float64
# 1986           float64
# 1987           float64
# 1988           float64
# 1989           float64
# 1990           float64
# 1991           float64
# ...

# %%
temp_T = gdp_df.set_index('gdp pc test').T

# %%
temp_T.head() #TODO: Come up with a better heading for the row_index column
# Out:
# gdp pc test  Abkhazia  Afghanistan  Akrotiri and Dhekelia     Albania  \
# 1800              NaN     472.0535                    NaN  601.215222
# 1801              NaN     472.0535                    NaN  601.839631
# 1802              NaN     472.0535                    NaN  602.464688
# 1803              NaN     472.0535                    NaN  603.090394
# 1804              NaN     472.0535                    NaN  603.716751
#
# gdp pc test     Algeria  American Samoa      Andorra      Angola    Anguilla  \
# 1800         766.253664      674.453726  1260.123256  359.932582  775.668711
# 1801         766.234779      674.453726  1262.214402  359.932582  775.668711
# 1802         766.215895      674.453726  1264.309018  359.932582  775.668711
# 1803         766.197011      674.453726  1266.407109  359.932582  775.668711
# 1804         766.178127      674.453726  1268.508683  359.932582  775.668711
#
# gdp pc test  Antigua and Barbuda  ...    Western Sahara     Vietnam  \
# ...

# %%
temp_T.dtypes

# %%
def year_income_by_country(income_year_df, year):
    incomes = income_year_df.loc[year]
    incomes = incomes.dropna()
    plt.hist(incomes, bins=50)
    plt.xlabel('income per person')
    plt.ylabel('number of countries')
    plt.title('Histogram of income per person vs number of countries')

# %%
year_income_by_country(temp_T, 2000)

# %%
temp_T.index.min()
# Out:
# 1800

# %%
19000 in temp_T.index
# Out:
# False

# %%
len(temp_T.index) - len(set(temp_T.index))
# Out:
# 0

# %%
temp = temp_T.T

# %%
temp
# Out:
#                                      1800         1801         1802  \
# gdp pc test
# Abkhazia                              NaN          NaN          NaN
# Afghanistan                    472.053500   472.053500   472.053500
# Akrotiri and Dhekelia                 NaN          NaN          NaN
# Albania                        601.215222   601.839631   602.464688
# Algeria                        766.253664   766.234779   766.215895
# American Samoa                 674.453726   674.453726   674.453726
# Andorra                       1260.123256  1262.214402  1264.309018
# Angola                         359.932582   359.932582   359.932582
# Anguilla                       775.668711   775.668711   775.668711
# Antigua and Barbuda            538.376199   538.376199   538.376199
# Argentina                      871.625269   871.625269   871.625269
# Armenia                        378.403254   378.403254   378.403254
# Aruba                          575.855054   575.855054   575.855054
# ...

# %%
# countries.merge(pd.DataFrame(temp[1801]), how="inner", left_on='Country', right_on=)

# %%
v = pd.DataFrame(temp[1801])

# %%
v.index = v.index.rename('Country')

# %%
ts1 = ['Andora', 'Angola', 'India']
ts2 = [10, 100, 1000]
d = {'col2': ts2}
df1 = pd.DataFrame(d, index=ts1)

# %%
incomes = temp_T.loc[1820]

# %%
incomes_df = pd.DataFrame(incomes)
incomes_df
# Out:
#                                      1820
# gdp pc test
# Abkhazia                              NaN
# Afghanistan                    472.053500
# Akrotiri and Dhekelia                 NaN
# Albania                        613.827381
# Algeria                        765.876054
# American Samoa                 674.453726
# Andorra                       1302.612118
# Angola                         359.932582
# Anguilla                       775.668711
# Antigua and Barbuda            538.376199
# Argentina                      871.625269
# Armenia                        378.403254
# Aruba                          575.855054
# Australia                      701.033111
# Austria                       1550.014330
# Azerbaijan                     478.129113
# Bahamas                       1409.188697
# Bahrain                        812.818268
# Bangladesh                     605.635027
# Barbados                      1017.813988
# Belarus                        514.550649
# ...

# %%
df1
# Out:
#      col1  col2
# 0  Andora    10
# 1  Angola   100
# 2   India  1000

# %%
t = temp_T.loc[1820]
t
# Out:
# gdp pc test
# Abkhazia                                NaN
# Afghanistan                      472.053500
# Akrotiri and Dhekelia                   NaN
# Albania                          613.827381
# Algeria                          765.876054
# American Samoa                   674.453726
# Andorra                         1302.612118
# Angola                           359.932582
# Anguilla                         775.668711
# Antigua and Barbuda              538.376199
# Argentina                        871.625269
# Armenia                          378.403254
# Aruba                            575.855054
# Australia                        701.033111
# Austria                         1550.014330
# Azerbaijan                       478.129113
# Bahamas                         1409.188697
# Bahrain                          812.818268
# Bangladesh                       605.635027
# Barbados                        1017.813988
# Belarus                          514.550649
# ...

# %%
df2 = pd.DataFrame(data=t.values, index=t.index)

# %%
df2
# Out:
#                                         0
# gdp pc test
# Abkhazia                              NaN
# Afghanistan                    472.053500
# Akrotiri and Dhekelia                 NaN
# Albania                        613.827381
# Algeria                        765.876054
# American Samoa                 674.453726
# Andorra                       1302.612118
# Angola                         359.932582
# Anguilla                       775.668711
# Antigua and Barbuda            538.376199
# Argentina                      871.625269
# Armenia                        378.403254
# Aruba                          575.855054
# Australia                      701.033111
# Austria                       1550.014330
# Azerbaijan                     478.129113
# Bahamas                       1409.188697
# Bahrain                        812.818268
# Bangladesh                     605.635027
# Barbados                      1017.813988
# Belarus                        514.550649
# ...

# %%
df1
# Out:
#         col2
# Andora    10
# Angola   100
# India   1000

# %%
df1.merge(df2, left_index=True, right_index=True)
# Out:
#         col2           0
# Angola   100  359.932582
# India   1000  559.963510

# %%
incs = temp_T.loc[1801]
df3 = pd.DataFrame(data=incs.values, index=incs.index)

# %%
merged_df = countries.merge(df3, left_on='Country', right_index=True, how='left')

# %%
merged_df.columns = ['Country', 'Region', 'Income']

# %%
merged_df.head()
# Out:
#     Country  Region      Income
# 0   Algeria  AFRICA  766.234779
# 1    Angola  AFRICA  359.932582
# 2     Benin  AFRICA  553.718301
# 3  Botswana  AFRICA  407.359342
# 4   Burkina  AFRICA         NaN

# %%
u = merged_df.dropna()[merged_df['Region'] == 'AFRICA']
v = merged_df.dropna()[merged_df['Region'] == 'ASIA']
# Out:
# /Users/abhishekkadian/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# /Users/abhishekkadian/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   from ipykernel import kernelapp as app

# %%
merged_df.boxplot(column='Income', by='Region')
