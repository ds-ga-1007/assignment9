# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
da = pd.read_csv('countries.csv',index_col=0)

# %%
da.head()
# Out:
#           Region
# Country
# Algeria   AFRICA
# Angola    AFRICA
# Benin     AFRICA
# Botswana  AFRICA
# Burkina   AFRICA

# %%
a = pd.read_excel('indicator gapminder gdp_per_capita_ppp.xlsx',index_col=0)

# %%
a.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012],
#            dtype='int64', length=213)

# %%
a.head()
# Out:
#                              1800        1801        1802        1803  \
# gdp pc test
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            472.053500  472.053500  472.053500  472.053500
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                601.215222  601.839631  602.464688  603.090394
# Algeria                766.253664  766.234779  766.215895  766.197011
#
#                              1804        1805        1806        1807  \
# gdp pc test
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            472.053500  472.053500  472.053500  472.053500
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                603.716751  604.343757  604.971415  605.599725
# Algeria                766.178127  766.159244  766.140362  766.121480
#
#                              1808        1809     ...              2003  \
# ...

# %%
pd.merge(da,a,left_index=True,right_index=True)
# Out:
#                                Region         1800         1801         1802  \
# Afghanistan                      ASIA   472.053500   472.053500   472.053500
# Albania                        EUROPE   601.215222   601.839631   602.464688
# Algeria                        AFRICA   766.253664   766.234779   766.215895
# Andorra                        EUROPE  1260.123256  1262.214402  1264.309018
# Angola                         AFRICA   359.932582   359.932582   359.932582
# Antigua and Barbuda     NORTH AMERICA   538.376199   538.376199   538.376199
# Argentina               SOUTH AMERICA   871.625269   871.625269   871.625269
# Armenia                        EUROPE   378.403254   378.403254   378.403254
# Australia                     OCEANIA   671.478209   672.925915   674.376742
# Austria                        EUROPE  1434.507479  1440.072847  1445.659806
# Azerbaijan                     EUROPE   477.152815   477.201582   477.250355
# ...

# %%
db = pd.read_excel('indicator gapminder gdp_per_capita_ppp.xlsx',index_col=0).T

# %%
db.columns
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'Western Sahara', 'Vietnam', 'Virgin Islands (U.S.)',
#        'Yemen Arab Republic (Former)', 'Yemen Democratic (Former)',
#        'Yemen, Rep.', 'Yugoslavia', 'Zambia', 'Zimbabwe', 'Åland'],
#       dtype='object', name='gdp pc test', length=260)

# %%
plt.hist(a[1900].dropna().values)
# Out:
# (array([ 95.,  60.,  26.,  15.,  10.,   4.,   5.,   0.,   3.,   2.]),
#  array([  311.73337106,   942.99050485,  1574.24763864,  2205.50477243,
#          2836.76190623,  3468.01904002,  4099.27617381,  4730.53330761,
#          5361.7904414 ,  5993.04757519,  6624.30470898]),
#  <a list of 10 Patch objects>)

# %%
a.head()
# Out:
#                              1800        1801        1802        1803  \
# gdp pc test
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            472.053500  472.053500  472.053500  472.053500
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                601.215222  601.839631  602.464688  603.090394
# Algeria                766.253664  766.234779  766.215895  766.197011
#
#                              1804        1805        1806        1807  \
# gdp pc test
# Abkhazia                      NaN         NaN         NaN         NaN
# Afghanistan            472.053500  472.053500  472.053500  472.053500
# Akrotiri and Dhekelia         NaN         NaN         NaN         NaN
# Albania                603.716751  604.343757  604.971415  605.599725
# Algeria                766.178127  766.159244  766.140362  766.121480
#
#                              1808        1809     ...              2003  \
# ...

# %%
a = pd.DataFrame(a[1900])

# %%
a.head()
# Out:
#                               1900
# gdp pc test
# Abkhazia                       NaN
# Afghanistan             612.004114
# Akrotiri and Dhekelia          NaN
# Albania                1048.259228
# Algeria                1787.410266

# %%
pd.merge(a,da,right_on="Country")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-c9906c676838> in <module>()
#       1
# ----> 2 pd.merge(a,da,right_on="Country")
#
# /home/peimengsui/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/tools/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy, indicator=indicator)
#      39     return op.get_result()
#      40 if __debug__:
#
# /home/peimengsui/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/tools/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
# ...

# %%
plt.hist(a[1999].dropna().values)
plt.title("distribution of income per person across all countries_"+str(1999))
plt.xlabel("income_per_person")
plt.ylabel("count")

# %%
def merge_by_year(coutries,income,year):
    '''
    this function merges the countries and income data sets for any given year
    '''
    income_year = pd.DataFrame(income[year])
    merged = pd.merge(coutries,income_year,left_index=True,right_index=True)
    merged["Country"] = merged.index
    merged.rename(columns = {year:'Income'}, inplace = True)
    return merged

# %%
merged = merge_by_year(da,a,1999)

# %%
merged.head()
# Out:
#              Region        Income      Country
# Afghanistan    ASIA    670.987221  Afghanistan
# Albania      EUROPE   3928.275138      Albania
# Algeria      AFRICA   5048.615566      Algeria
# Andorra      EUROPE  30144.971656      Andorra
# Angola       AFRICA   2417.181021       Angola

# %%
merged.columns
# Out:
# Index(['Region', 1999], dtype='object')

# %%
merged.rename(columns = {1999:'Income'}, inplace = True)

# %%
merged.head()
# Out:
#              Region        Income
# Afghanistan    ASIA    670.987221
# Albania      EUROPE   3928.275138
# Algeria      AFRICA   5048.615566
# Andorra      EUROPE  30144.971656
# Angola       AFRICA   2417.181021

# %%
da.shape
# Out:
# (194, 1)

# %%
merged.shape
# Out:
# (177, 3)

# %%
plt.hist(merged["Income"].dropna().values)
# Out:
# (array([ 116.,   21.,   12.,   17.,    6.,    2.,    0.,    2.,    0.,    1.]),
#  array([   455.4120959 ,   8518.6799756 ,  16581.9478553 ,  24645.215735  ,
#          32708.4836147 ,  40771.7514944 ,  48835.01937409,  56898.28725379,
#          64961.55513349,  73024.82301319,  81088.09089289]),
#  <a list of 10 Patch objects>)
