# %%
import pandas as pd
import matplotlib.pyplot as plt


countries = pd.read_csv('countries.csv')
income = pd.read_excel('indicator gapminder gdp_per_capita_ppp.xlsx', index_col=0).transpose()
income
# Out:
# gdp pc test  Abkhazia  Afghanistan  Akrotiri and Dhekelia     Albania  \
# 1800              NaN     472.0535                    NaN  601.215222
# 1801              NaN     472.0535                    NaN  601.839631
# 1802              NaN     472.0535                    NaN  602.464688
# 1803              NaN     472.0535                    NaN  603.090394
# 1804              NaN     472.0535                    NaN  603.716751
#
# gdp pc test     Algeria  American Samoa      Andorra      Angola    Anguilla  \
# 1800         766.253664      674.453726  1260.123256  359.932582  775.668711
# 1801         766.234779      674.453726  1262.214402  359.932582  775.668711
# 1802         766.215895      674.453726  1264.309018  359.932582  775.668711
# 1803         766.197011      674.453726  1266.407109  359.932582  775.668711
# 1804         766.178127      674.453726  1268.508683  359.932582  775.668711
#
# gdp pc test  Antigua and Barbuda  ...    Western Sahara     Vietnam  \
# ...

# %%
income
# Out:
# Country  Abkhazia  Afghanistan  Akrotiri and Dhekelia      Albania  \
# 1800          NaN   472.053500                    NaN   601.215222
# 1801          NaN   472.053500                    NaN   601.839631
# 1802          NaN   472.053500                    NaN   602.464688
# 1803          NaN   472.053500                    NaN   603.090394
# 1804          NaN   472.053500                    NaN   603.716751
# 1805          NaN   472.053500                    NaN   604.343757
# 1806          NaN   472.053500                    NaN   604.971415
# 1807          NaN   472.053500                    NaN   605.599725
# 1808          NaN   472.053500                    NaN   606.228687
# 1809          NaN   472.053500                    NaN   606.858303
# 1810          NaN   472.053500                    NaN   607.488572
# 1811          NaN   472.053500                    NaN   608.119496
# 1812          NaN   472.053500                    NaN   608.751075
# ...

# %%
year_data = income.loc[1999].to_frame('Income')
year_data.index.names = ['Country']
result = countries.join(year_data, on = ['Country'], how = 'right', lsuffix='_x')

# %%
result.hist('Income', by='Region')
plt.savefig('box_' + str(1999) + '.pdf')

# %%
year_data.index.names = ['Country']

# %%
countries.join(year_data, on = ['Country'], how = 'right', lsuffix='_x')
# Out:
#                           Country  Region        Income
# 0                         Algeria  AFRICA   5048.615566
# 1                          Angola  AFRICA   2417.181021
# 2                           Benin  AFRICA   1272.796464
# 3                        Botswana  AFRICA   9416.670376
# 5                         Burundi  AFRICA    455.412096
# 6                        Cameroon  AFRICA   1770.650380
# 7                      Cape Verde  AFRICA   2168.686778
# 9                            Chad  AFRICA   1039.290389
# 10                        Comoros  AFRICA   1137.887465
# 13                       Djibouti  AFRICA   1901.116370
# 14                          Egypt  AFRICA   4482.937530
# 15              Equatorial Guinea  AFRICA   4623.257066
# 16                        Eritrea  AFRICA    877.606630
# 17                       Ethiopia  AFRICA    496.867976
# 18                          Gabon  AFRICA  13276.449872
# 19                         Gambia  AFRICA    672.495994
# ...
